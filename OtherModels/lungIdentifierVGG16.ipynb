# %%
import pandas as pd
import numpy as np
import os
import cv2

from metods import *

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, ZeroPadding2D
from tensorflow.keras.layers import BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras import models, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt
from matplotlib import image

from skimage.io import imread

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_CHANNELS = 1
PADDING = 40

models_folder = "models\\"

modelName = models_folder + "LungIdentifierModelVGG16.h5"

TRAINING_MODE = True
KAGGLE_MODE = False

healty_path = "C:\\Users\\ugur_\\Python Projects\\LungClassifier\\NIH Data\\Healty\\"
healty_mask_path = "C:\\Users\\ugur_\\Python Projects\\LungClassifier\\NIH Data\\Healty Mask\\"
healty_segmented_path = "C:\\Users\\ugur_\\Python Projects\\LungClassifier\\NIH Data\\Healty Segmented\\"

pneu_path = "C:\\Users\\ugur_\\Python Projects\\LungClassifier\\NIH Data\\Pneumothorax\\"
pneu_mask_path = "C:\\Users\\ugur_\\Python Projects\\LungClassifier\\NIH Data\\Pneumothorax Mask\\"
pneu_segmented_path = "C:\\Users\\ugur_\\Python Projects\\LungClassifier\\NIH Data\\Pneumothorax Segmented\\"

# %%
healty_segmented_images = os.listdir(healty_segmented_path)
pneu_segmented_images = os.listdir(pneu_segmented_path)

X_train = np.zeros((len(healty_segmented_images) + len(pneu_segmented_images), IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)
Y_train = np.zeros((len(healty_segmented_images) + len(pneu_segmented_images)), dtype=np.bool)

for i, img_id in enumerate(healty_segmented_images):
    file_name = healty_segmented_path + img_id

    img = readImages(file_name, is_gray=0)
    
    X_train[i] = img
    Y_train[i] = 0

for i, img_id in enumerate(pneu_segmented_images):
    file_name = pneu_segmented_path + img_id
    
    img = readImages(file_name, is_gray=0)
    
    X_train[len(healty_segmented_images) + i] = img
    Y_train[len(healty_segmented_images) + i] = 1

X_train = np.repeat(X_train[..., np.newaxis], 3, -1)
X_train = X_train.reshape(-1, 128, 128, 3)

Y_train = to_categorical(Y_train)

print(X_train.shape)
print(Y_train.shape)
# Out:
# (12001, 128, 128, 3)
# (12001, 2)

# %%
#Train Test Split
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=0.2, random_state=8)

# %%
from tensorflow.keras.applications import VGG16

input_layer=layers.Input(shape=(IMG_WIDTH, IMG_HEIGHT, 3))

model_vgg16=VGG16(weights='imagenet', input_tensor=input_layer, include_top=False)

last_layer=model_vgg16.output 

flatten=layers.Flatten()(last_layer) 

output_layer=layers.Dense(2, activation='softmax')(flatten)

model=models.Model(inputs=input_layer, outputs=output_layer)

for layer in model.layers[:-1]:
    layer.trainable=False

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 16386
# =================================================================
# Total params: 14,731,074
# Trainable params: 16,386
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
if TRAINING_MODE:
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    earlystopper = EarlyStopping(patience=25, verbose=1)
    learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.5, min_lr=0.00001)
    checkpoint = ModelCheckpoint(modelName, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint, learning_rate_reduction, earlystopper]

    history = model.fit(X_train/255.0, Y_train, validation_data=(X_test/255.0, Y_test), batch_size=16, epochs=100, callbacks=callbacks_list, shuffle=True)
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training ve Validation loss oranı')
    plt.legend()
    plt.figure()

    plt.plot(epochs, acc, 'bo', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
    plt.title('Training ve Validation Accuracy oranı')
    plt.legend()
    plt.figure()
else:
    model = load_model(modelName)
# Out:
# Epoch 1/100
# 600/600 [==============================] - 17s 21ms/step - loss: 0.3966 - accuracy: 0.8140 - val_loss: 0.3221 - val_accuracy: 0.8642
#
# Epoch 00001: val_accuracy improved from -inf to 0.86422, saving model to models\LungIdentifierModelVGG16.h5
# Epoch 2/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.2955 - accuracy: 0.8702 - val_loss: 0.2957 - val_accuracy: 0.8788
#
# Epoch 00002: val_accuracy improved from 0.86422 to 0.87880, saving model to models\LungIdentifierModelVGG16.h5
# Epoch 3/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.2757 - accuracy: 0.8812 - val_loss: 0.3041 - val_accuracy: 0.8759
#
# Epoch 00003: val_accuracy did not improve from 0.87880
# Epoch 4/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.2586 - accuracy: 0.8901 - val_loss: 0.2886 - val_accuracy: 0.8792
#
# Epoch 00004: val_accuracy improved from 0.87880 to 0.87922, saving model to models\LungIdentifierModelVGG16.h5
# Epoch 5/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.2680 - accuracy: 0.8877 - val_loss: 0.4694 - val_accuracy: 0.8459
#
# Epoch 00005: val_accuracy did not improve from 0.87922
# Epoch 6/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.2395 - accuracy: 0.9005 - val_loss: 0.4261 - val_accuracy: 0.8084
#
# Epoch 00006: val_accuracy did not improve from 0.87922
# Epoch 7/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.2442 - accuracy: 0.8924 - val_loss: 0.3531 - val_accuracy: 0.8467
#
# Epoch 00007: val_accuracy did not improve from 0.87922
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 8/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.2129 - accuracy: 0.9101 - val_loss: 0.2973 - val_accuracy: 0.8776
#
# Epoch 00008: val_accuracy did not improve from 0.87922
# Epoch 9/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.2031 - accuracy: 0.9138 - val_loss: 0.2987 - val_accuracy: 0.8696
#
# Epoch 00009: val_accuracy did not improve from 0.87922
# Epoch 10/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.2004 - accuracy: 0.9124 - val_loss: 0.3239 - val_accuracy: 0.8571
#
# Epoch 00010: val_accuracy did not improve from 0.87922
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 11/100
# 600/600 [==============================] - 10s 17ms/step - loss: 0.1884 - accuracy: 0.9239 - val_loss: 0.3090 - val_accuracy: 0.8830
#
# Epoch 00011: val_accuracy improved from 0.87922 to 0.88297, saving model to models\LungIdentifierModelVGG16.h5
# Epoch 12/100
# 600/600 [==============================] - 10s 17ms/step - loss: 0.1859 - accuracy: 0.9226 - val_loss: 0.2896 - val_accuracy: 0.8855
#
# Epoch 00012: val_accuracy improved from 0.88297 to 0.88546, saving model to models\LungIdentifierModelVGG16.h5
# Epoch 13/100
# 600/600 [==============================] - 10s 17ms/step - loss: 0.1863 - accuracy: 0.9220 - val_loss: 0.2939 - val_accuracy: 0.8842
#
# Epoch 00013: val_accuracy did not improve from 0.88546
# Epoch 14/100
# 600/600 [==============================] - 10s 17ms/step - loss: 0.1820 - accuracy: 0.9263 - val_loss: 0.3225 - val_accuracy: 0.8805
#
# Epoch 00014: val_accuracy did not improve from 0.88546
# Epoch 15/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1754 - accuracy: 0.9316 - val_loss: 0.3026 - val_accuracy: 0.8838
#
# Epoch 00015: val_accuracy did not improve from 0.88546
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 16/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1755 - accuracy: 0.9303 - val_loss: 0.2948 - val_accuracy: 0.8846
#
# Epoch 00016: val_accuracy did not improve from 0.88546
# Epoch 17/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1679 - accuracy: 0.9349 - val_loss: 0.3016 - val_accuracy: 0.8867
#
# Epoch 00017: val_accuracy improved from 0.88546 to 0.88671, saving model to models\LungIdentifierModelVGG16.h5
# Epoch 18/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1679 - accuracy: 0.9349 - val_loss: 0.2884 - val_accuracy: 0.8838
#
# Epoch 00018: val_accuracy did not improve from 0.88671
# Epoch 19/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1719 - accuracy: 0.9296 - val_loss: 0.2951 - val_accuracy: 0.8842
#
# Epoch 00019: val_accuracy did not improve from 0.88671
# Epoch 20/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1660 - accuracy: 0.9355 - val_loss: 0.2902 - val_accuracy: 0.8830
#
# Epoch 00020: val_accuracy did not improve from 0.88671
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 21/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1698 - accuracy: 0.9342 - val_loss: 0.2895 - val_accuracy: 0.8813
#
# Epoch 00021: val_accuracy did not improve from 0.88671
# Epoch 22/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1690 - accuracy: 0.9340 - val_loss: 0.2895 - val_accuracy: 0.8834
#
# Epoch 00022: val_accuracy did not improve from 0.88671
# Epoch 23/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1659 - accuracy: 0.9352 - val_loss: 0.2895 - val_accuracy: 0.8821
#
# Epoch 00023: val_accuracy did not improve from 0.88671
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 24/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1630 - accuracy: 0.9340 - val_loss: 0.2893 - val_accuracy: 0.8838
#
# Epoch 00024: val_accuracy did not improve from 0.88671
# Epoch 25/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1603 - accuracy: 0.9393 - val_loss: 0.2890 - val_accuracy: 0.8817
#
# Epoch 00025: val_accuracy did not improve from 0.88671
# Epoch 26/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1578 - accuracy: 0.9422 - val_loss: 0.2893 - val_accuracy: 0.8813
#
# Epoch 00026: val_accuracy did not improve from 0.88671
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 27/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1681 - accuracy: 0.9362 - val_loss: 0.2892 - val_accuracy: 0.8809
#
# Epoch 00027: val_accuracy did not improve from 0.88671
# Epoch 28/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1660 - accuracy: 0.9360 - val_loss: 0.2891 - val_accuracy: 0.8817
#
# Epoch 00028: val_accuracy did not improve from 0.88671
# Epoch 29/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1633 - accuracy: 0.9381 - val_loss: 0.2893 - val_accuracy: 0.8825
#
# Epoch 00029: val_accuracy did not improve from 0.88671
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 30/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1640 - accuracy: 0.9354 - val_loss: 0.2891 - val_accuracy: 0.8825
#
# Epoch 00030: val_accuracy did not improve from 0.88671
# Epoch 31/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1591 - accuracy: 0.9419 - val_loss: 0.2895 - val_accuracy: 0.8834
#
# Epoch 00031: val_accuracy did not improve from 0.88671
# Epoch 32/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1645 - accuracy: 0.9338 - val_loss: 0.2893 - val_accuracy: 0.8825
#
# Epoch 00032: val_accuracy did not improve from 0.88671
# Epoch 33/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1643 - accuracy: 0.9368 - val_loss: 0.2900 - val_accuracy: 0.8838
#
# Epoch 00033: val_accuracy did not improve from 0.88671
# Epoch 34/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1613 - accuracy: 0.9366 - val_loss: 0.2896 - val_accuracy: 0.8834
#
# Epoch 00034: val_accuracy did not improve from 0.88671
# Epoch 35/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1657 - accuracy: 0.9355 - val_loss: 0.2903 - val_accuracy: 0.8801
#
# Epoch 00035: val_accuracy did not improve from 0.88671
# Epoch 36/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1671 - accuracy: 0.9355 - val_loss: 0.2894 - val_accuracy: 0.8817
#
# Epoch 00036: val_accuracy did not improve from 0.88671
# Epoch 37/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1579 - accuracy: 0.9418 - val_loss: 0.2894 - val_accuracy: 0.8825
#
# Epoch 00037: val_accuracy did not improve from 0.88671
# Epoch 38/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1613 - accuracy: 0.9372 - val_loss: 0.2894 - val_accuracy: 0.8825
#
# Epoch 00038: val_accuracy did not improve from 0.88671
# Epoch 39/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1561 - accuracy: 0.9387 - val_loss: 0.2894 - val_accuracy: 0.8825
#
# Epoch 00039: val_accuracy did not improve from 0.88671
# Epoch 40/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1619 - accuracy: 0.9376 - val_loss: 0.2894 - val_accuracy: 0.8821
#
# Epoch 00040: val_accuracy did not improve from 0.88671
# Epoch 41/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1554 - accuracy: 0.9407 - val_loss: 0.2898 - val_accuracy: 0.8809
#
# Epoch 00041: val_accuracy did not improve from 0.88671
# Epoch 42/100
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1573 - accuracy: 0.9380 - val_loss: 0.2895 - val_accuracy: 0.8825
#
# Epoch 00042: val_accuracy did not improve from 0.88671
# Epoch 43/100
# 600/600 [==============================] - 10s 16ms/step - loss: 0.1613 - accuracy: 0.9390 - val_loss: 0.2895 - val_accuracy: 0.8821
#
# Epoch 00043: val_accuracy did not improve from 0.88671
# Epoch 00043: early stopping

# %%
model = load_model(modelName)

df_test = pd.DataFrame()

Y_test_normal = np.argmax(Y_test, axis=-1)

print(Y_test_normal.shape)

df_test['type'] = Y_test_normal

df_test = df_test.reset_index(drop=True)

df_test.head(10)

def fixImages(folder_name):
    for img_name in os.listdir(folder_name):
        try:
            readImages(folder_name + img_name)
        except Exception as ex:
            os.remove(folder_name + img_name)
# Out:
# (2401,)

# %%
preds = np.argmax(model.predict(X_test/255.0), axis=-1)

df_test['preds'] = np.round(preds)
df_test['preds'] = df_test['preds'].apply(np.int)

wrongs_df = df_test.loc[df_test['type'] != df_test['preds']]

print(f"{len(df_test)} hücre fotoğrafı arasından {len(wrongs_df)} tanesi yanlış tahmin edildi. Doğruluk oranı \
# %{100 - (len(wrongs_df) * 100 / len(df_test))}")

df_test.head(10)
# Out:
# 2401 hücre fotoğrafı arasından 272 tanesi yanlış tahmin edildi. Doğruluk oranı %88.67138692211579
#    type  preds
# 0     1      0
# 1     1      0
# 2     1      1
# 3     1      0
# 4     0      0
# 5     1      1
# 6     1      1
# 7     1      1
# 8     0      0
# 9     0      0

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

cm1 = confusion_matrix(df_test[['type']], df_test['preds'])
sn.heatmap(cm1, annot=True, annot_kws={"size": 16}, fmt="d")

total1=sum(sum(cm1))
#####from confusion matrix calculate accuracy
accuracy1=(cm1[0,0]+cm1[1,1])/total1
print ('Accuracy : ', accuracy1)

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Sensitivity : ', sensitivity1 )

specificity1 = cm1[1,1]/(cm1[1,0]+cm1[1,1])
print('Specificity : ', specificity1)
# Out:
# Accuracy :  0.8867138692211578
# Sensitivity :  0.9493464052287581
# Specificity :  0.8215802888700084

# %%
plt.figure(figsize=(10,10))
plt.axis('Off')

start_from = 10

for i in range(1, 10):
    plt.subplot(3,3,i)
    test_image = X_test[i + start_from, :, :, 0]
    plt.imshow((test_image), cmap=plt.cm.bone)

    true = df_test.loc[i + start_from, 'type']
    pred = df_test.loc[i + start_from, 'preds']
    result = 'True: ' + str(int(true)) + ' Pred: ' + str(pred)

    plt.title(result, fontsize=14)
    plt.axis('off')


plt.tight_layout()
plt.show()
