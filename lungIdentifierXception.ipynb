# %%
import pandas as pd
import numpy as np
import os
import cv2

from metods import *

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, ZeroPadding2D
from tensorflow.keras.layers import BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras import models, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt
from matplotlib import image

from skimage.io import imread

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_CHANNELS = 1
PADDING = 40

models_folder = "models\\"

modelName = models_folder + "LungIdentifierModelXception.h5"

TRAINING_MODE = True
KAGGLE_MODE = False

healty_path = "C:\\Users\\ugur_\\Python Projects\\LungClassifier\\NIH Data\\Healty\\"
healty_mask_path = "C:\\Users\\ugur_\\Python Projects\\LungClassifier\\NIH Data\\Healty Mask\\"
healty_segmented_path = "C:\\Users\\ugur_\\Python Projects\\LungClassifier\\NIH Data\\Healty Segmented\\"

pneu_path = "C:\\Users\\ugur_\\Python Projects\\LungClassifier\\NIH Data\\Pneumothorax\\"
pneu_mask_path = "C:\\Users\\ugur_\\Python Projects\\LungClassifier\\NIH Data\\Pneumothorax Mask\\"
pneu_segmented_path = "C:\\Users\\ugur_\\Python Projects\\LungClassifier\\NIH Data\\Pneumothorax Segmented\\"

# %%
healty_segmented_images = os.listdir(healty_segmented_path)
pneu_segmented_images = os.listdir(pneu_segmented_path)

X_train = np.zeros((len(healty_segmented_images) + len(pneu_segmented_images), IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)
Y_train = np.zeros((len(healty_segmented_images) + len(pneu_segmented_images)), dtype=np.bool)

for i, img_id in enumerate(healty_segmented_images):
    file_name = healty_segmented_path + img_id

    img = readImages(file_name, is_gray=0)
    
    X_train[i] = img
    Y_train[i] = 0

for i, img_id in enumerate(pneu_segmented_images):
    file_name = pneu_segmented_path + img_id
    
    img = readImages(file_name, is_gray=0)
    
    X_train[len(healty_segmented_images) + i] = img
    Y_train[len(healty_segmented_images) + i] = 1

X_train = np.repeat(X_train[..., np.newaxis], 3, -1)
X_train = X_train.reshape(-1, 128, 128, 3)

Y_train = to_categorical(Y_train)

print(X_train.shape)
print(Y_train.shape)
# Out:
# (12001, 128, 128, 3)
# (12001, 2)

# %%
#Train Test Split
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=0.2, random_state=8)

# %%
from tensorflow.keras.applications import Xception

input_layer=layers.Input(shape=(IMG_WIDTH, IMG_HEIGHT, 3))

model_Xception=Xception(weights='imagenet', input_tensor=input_layer, include_top=False)

last_layer=model_Xception.output 

flatten=layers.Flatten()(last_layer) 

output_layer=layers.Dense(2, activation='softmax')(flatten)

model=models.Model(inputs=input_layer, outputs=output_layer)

for layer in model.layers[:-1]:
    layer.trainable=False

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 7s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 63, 63, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 63, 63, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 63, 63, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 61, 61, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 61, 61, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 61, 61, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 61, 61, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 61, 61, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 61, 61, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 61, 61, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 61, 61, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 31, 31, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 31, 31, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 31, 31, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 31, 31, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 31, 31, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 31, 31, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 31, 31, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 31, 31, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 31, 31, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 31, 31, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 16, 16, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 16, 16, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 16, 16, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 16, 16, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 16, 16, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 16, 16, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 16, 16, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 8, 728)    186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 8, 8, 728)    0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 8, 728)    2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 728)    0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 8, 8, 728)    0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 8, 8, 728)    0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 8, 8, 728)    0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 8, 728)    0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 8, 8, 728)    0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 8, 8, 728)    0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 8, 8, 728)    0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 728)    0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 8, 8, 728)    0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 8, 8, 728)    0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 8, 8, 728)    0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 728)    0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 8, 8, 728)    0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 8, 8, 728)    0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 8, 8, 728)    0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 728)    0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 8, 8, 728)    0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 8, 8, 728)    0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 8, 8, 728)    0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 728)    0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 8, 8, 728)    0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 8, 8, 728)    536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 8, 8, 728)    2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 8, 8, 728)    0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 8, 8, 728)    536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 8, 8, 728)    2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 8, 8, 728)    0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 8, 8, 728)    536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 8, 8, 728)    2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 728)    0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 8, 8, 728)    0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 8, 8, 728)    536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 8, 8, 728)    2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 8, 8, 728)    0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 8, 8, 728)    536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 8, 8, 728)    2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 8, 8, 728)    0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 8, 8, 728)    536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 8, 8, 728)    2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 728)    0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 8, 8, 728)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 8, 8, 728)    536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 8, 8, 728)    2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 8, 8, 728)    0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 8, 8, 728)    536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 8, 8, 728)    2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 8, 8, 728)    0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 8, 8, 728)    536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 8, 8, 728)    2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 728)    0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 8, 8, 728)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 8, 8, 728)    536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 8, 8, 728)    2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 8, 8, 728)    0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 8, 8, 1024)   752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 8, 8, 1024)   4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 4, 4, 1024)   745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 4, 4, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 4, 4, 1024)   4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, 4, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 4, 4, 1536)   1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 4, 4, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 4, 4, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 4, 4, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 4, 4, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 4, 4, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 32768)        0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            65538       flatten[0][0]
# ==================================================================================================
# Total params: 20,927,018
# Trainable params: 65,538
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %%
if TRAINING_MODE:
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    earlystopper = EarlyStopping(patience=25, verbose=1)
    learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.5, min_lr=0.00001)
    checkpoint = ModelCheckpoint(modelName, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint, learning_rate_reduction, earlystopper]

    history = model.fit(X_train/255.0, Y_train, validation_data=(X_test/255.0, Y_test), batch_size=16, epochs=100, callbacks=callbacks_list, shuffle=True)
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training ve Validation loss oranı')
    plt.legend()
    plt.figure()

    plt.plot(epochs, acc, 'bo', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
    plt.title('Training ve Validation Accuracy oranı')
    plt.legend()
    plt.figure()
else:
    model = load_model(modelName)
# Out:
# Epoch 1/100
# 600/600 [==============================] - 26s 28ms/step - loss: 1.6970 - accuracy: 0.7414 - val_loss: 0.8069 - val_accuracy: 0.7697
#
# Epoch 00001: val_accuracy improved from -inf to 0.76968, saving model to models\LungIdentifierModelXception.h5
# Epoch 2/100
# 600/600 [==============================] - 13s 21ms/step - loss: 0.8718 - accuracy: 0.8164 - val_loss: 1.0691 - val_accuracy: 0.7651
#
# Epoch 00002: val_accuracy did not improve from 0.76968
# Epoch 3/100
# 600/600 [==============================] - 13s 21ms/step - loss: 0.9279 - accuracy: 0.8293 - val_loss: 0.8826 - val_accuracy: 0.8463
#
# Epoch 00003: val_accuracy improved from 0.76968 to 0.84631, saving model to models\LungIdentifierModelXception.h5
# Epoch 4/100
# 600/600 [==============================] - 13s 21ms/step - loss: 0.8605 - accuracy: 0.8500 - val_loss: 1.3541 - val_accuracy: 0.8292
#
# Epoch 00004: val_accuracy did not improve from 0.84631
# Epoch 5/100
# 600/600 [==============================] - 13s 21ms/step - loss: 0.8572 - accuracy: 0.8570 - val_loss: 0.9253 - val_accuracy: 0.8059
#
# Epoch 00005: val_accuracy did not improve from 0.84631
# Epoch 6/100
# 600/600 [==============================] - 12s 20ms/step - loss: 0.7394 - accuracy: 0.8647 - val_loss: 1.1589 - val_accuracy: 0.8117
#
# Epoch 00006: val_accuracy did not improve from 0.84631
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.4759 - accuracy: 0.8875 - val_loss: 0.8015 - val_accuracy: 0.8388
#
# Epoch 00007: val_accuracy did not improve from 0.84631
# Epoch 8/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.3808 - accuracy: 0.8935 - val_loss: 0.7901 - val_accuracy: 0.8434
#
# Epoch 00008: val_accuracy did not improve from 0.84631
# Epoch 9/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.2978 - accuracy: 0.9107 - val_loss: 0.7961 - val_accuracy: 0.8305
#
# Epoch 00009: val_accuracy did not improve from 0.84631
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 10/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.2271 - accuracy: 0.9212 - val_loss: 0.7805 - val_accuracy: 0.8276
#
# Epoch 00010: val_accuracy did not improve from 0.84631
# Epoch 11/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.1865 - accuracy: 0.9310 - val_loss: 0.6016 - val_accuracy: 0.8405
#
# Epoch 00011: val_accuracy did not improve from 0.84631
# Epoch 12/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.1796 - accuracy: 0.9324 - val_loss: 0.5949 - val_accuracy: 0.8384
#
# Epoch 00012: val_accuracy did not improve from 0.84631
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 13/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.1364 - accuracy: 0.9453 - val_loss: 0.6178 - val_accuracy: 0.8426
#
# Epoch 00013: val_accuracy did not improve from 0.84631
# Epoch 14/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.1205 - accuracy: 0.9527 - val_loss: 0.5615 - val_accuracy: 0.8401
#
# Epoch 00014: val_accuracy did not improve from 0.84631
# Epoch 15/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.1294 - accuracy: 0.9488 - val_loss: 0.5595 - val_accuracy: 0.8367
#
# Epoch 00015: val_accuracy did not improve from 0.84631
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 16/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.1020 - accuracy: 0.9613 - val_loss: 0.5617 - val_accuracy: 0.8359
#
# Epoch 00016: val_accuracy did not improve from 0.84631
# Epoch 17/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.1062 - accuracy: 0.9593 - val_loss: 0.5354 - val_accuracy: 0.8397
#
# Epoch 00017: val_accuracy did not improve from 0.84631
# Epoch 18/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0996 - accuracy: 0.9630 - val_loss: 0.5437 - val_accuracy: 0.8376
#
# Epoch 00018: val_accuracy did not improve from 0.84631
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 19/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0932 - accuracy: 0.9649 - val_loss: 0.5409 - val_accuracy: 0.8413
#
# Epoch 00019: val_accuracy did not improve from 0.84631
# Epoch 20/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0879 - accuracy: 0.9687 - val_loss: 0.5252 - val_accuracy: 0.8417
#
# Epoch 00020: val_accuracy did not improve from 0.84631
# Epoch 21/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0855 - accuracy: 0.9696 - val_loss: 0.5508 - val_accuracy: 0.8442
#
# Epoch 00021: val_accuracy did not improve from 0.84631
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 22/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0833 - accuracy: 0.9716 - val_loss: 0.5276 - val_accuracy: 0.8413
#
# Epoch 00022: val_accuracy did not improve from 0.84631
# Epoch 23/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0816 - accuracy: 0.9726 - val_loss: 0.5304 - val_accuracy: 0.8409
#
# Epoch 00023: val_accuracy did not improve from 0.84631
# Epoch 24/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0791 - accuracy: 0.9751 - val_loss: 0.5311 - val_accuracy: 0.8392
#
# Epoch 00024: val_accuracy did not improve from 0.84631
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 25/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0784 - accuracy: 0.9760 - val_loss: 0.5306 - val_accuracy: 0.8388
#
# Epoch 00025: val_accuracy did not improve from 0.84631
# Epoch 26/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0791 - accuracy: 0.9755 - val_loss: 0.5329 - val_accuracy: 0.8426
#
# Epoch 00026: val_accuracy did not improve from 0.84631
# Epoch 27/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0813 - accuracy: 0.9754 - val_loss: 0.5312 - val_accuracy: 0.8397
#
# Epoch 00027: val_accuracy did not improve from 0.84631
# Epoch 28/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0754 - accuracy: 0.9754 - val_loss: 0.5318 - val_accuracy: 0.8442
#
# Epoch 00028: val_accuracy did not improve from 0.84631
# Epoch 29/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0750 - accuracy: 0.9783 - val_loss: 0.5264 - val_accuracy: 0.8388
#
# Epoch 00029: val_accuracy did not improve from 0.84631
# Epoch 30/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0751 - accuracy: 0.9768 - val_loss: 0.5311 - val_accuracy: 0.8430
#
# Epoch 00030: val_accuracy did not improve from 0.84631
# Epoch 31/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0802 - accuracy: 0.9733 - val_loss: 0.5223 - val_accuracy: 0.8430
#
# Epoch 00031: val_accuracy did not improve from 0.84631
# Epoch 32/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0727 - accuracy: 0.9782 - val_loss: 0.5238 - val_accuracy: 0.8426
#
# Epoch 00032: val_accuracy did not improve from 0.84631
# Epoch 33/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0743 - accuracy: 0.9788 - val_loss: 0.5299 - val_accuracy: 0.8363
#
# Epoch 00033: val_accuracy did not improve from 0.84631
# Epoch 34/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0721 - accuracy: 0.9791 - val_loss: 0.5288 - val_accuracy: 0.8372
#
# Epoch 00034: val_accuracy did not improve from 0.84631
# Epoch 35/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0738 - accuracy: 0.9770 - val_loss: 0.5246 - val_accuracy: 0.8392
#
# Epoch 00035: val_accuracy did not improve from 0.84631
# Epoch 36/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0727 - accuracy: 0.9802 - val_loss: 0.5282 - val_accuracy: 0.8413
#
# Epoch 00036: val_accuracy did not improve from 0.84631
# Epoch 37/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0742 - accuracy: 0.9781 - val_loss: 0.5265 - val_accuracy: 0.8384
#
# Epoch 00037: val_accuracy did not improve from 0.84631
# Epoch 38/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0730 - accuracy: 0.9756 - val_loss: 0.5312 - val_accuracy: 0.8355
#
# Epoch 00038: val_accuracy did not improve from 0.84631
# Epoch 39/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0750 - accuracy: 0.9769 - val_loss: 0.5293 - val_accuracy: 0.8376
#
# Epoch 00039: val_accuracy did not improve from 0.84631
# Epoch 40/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0710 - accuracy: 0.9793 - val_loss: 0.5277 - val_accuracy: 0.8397
#
# Epoch 00040: val_accuracy did not improve from 0.84631
# Epoch 41/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0671 - accuracy: 0.9794 - val_loss: 0.5291 - val_accuracy: 0.8430
#
# Epoch 00041: val_accuracy did not improve from 0.84631
# Epoch 42/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0750 - accuracy: 0.9800 - val_loss: 0.5260 - val_accuracy: 0.8392
#
# Epoch 00042: val_accuracy did not improve from 0.84631
# Epoch 43/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0764 - accuracy: 0.9767 - val_loss: 0.5275 - val_accuracy: 0.8401
#
# Epoch 00043: val_accuracy did not improve from 0.84631
# Epoch 44/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0721 - accuracy: 0.9806 - val_loss: 0.5262 - val_accuracy: 0.8409
#
# Epoch 00044: val_accuracy did not improve from 0.84631
# Epoch 45/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0729 - accuracy: 0.9771 - val_loss: 0.5257 - val_accuracy: 0.8397
#
# Epoch 00045: val_accuracy did not improve from 0.84631
# Epoch 46/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0668 - accuracy: 0.9818 - val_loss: 0.5226 - val_accuracy: 0.8388
#
# Epoch 00046: val_accuracy did not improve from 0.84631
# Epoch 47/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0692 - accuracy: 0.9786 - val_loss: 0.5326 - val_accuracy: 0.8430
#
# Epoch 00047: val_accuracy did not improve from 0.84631
# Epoch 48/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0708 - accuracy: 0.9800 - val_loss: 0.5269 - val_accuracy: 0.8392
#
# Epoch 00048: val_accuracy did not improve from 0.84631
# Epoch 49/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0731 - accuracy: 0.9782 - val_loss: 0.5290 - val_accuracy: 0.8409
#
# Epoch 00049: val_accuracy did not improve from 0.84631
# Epoch 50/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0707 - accuracy: 0.9806 - val_loss: 0.5318 - val_accuracy: 0.8401
#
# Epoch 00050: val_accuracy did not improve from 0.84631
# Epoch 51/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0723 - accuracy: 0.9798 - val_loss: 0.5282 - val_accuracy: 0.8401
#
# Epoch 00051: val_accuracy did not improve from 0.84631
# Epoch 52/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0681 - accuracy: 0.9818 - val_loss: 0.5243 - val_accuracy: 0.8405
#
# Epoch 00052: val_accuracy did not improve from 0.84631
# Epoch 53/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0698 - accuracy: 0.9794 - val_loss: 0.5309 - val_accuracy: 0.8417
#
# Epoch 00053: val_accuracy did not improve from 0.84631
# Epoch 54/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0705 - accuracy: 0.9799 - val_loss: 0.5231 - val_accuracy: 0.8409
#
# Epoch 00054: val_accuracy did not improve from 0.84631
# Epoch 55/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0711 - accuracy: 0.9795 - val_loss: 0.5221 - val_accuracy: 0.8397
#
# Epoch 00055: val_accuracy did not improve from 0.84631
# Epoch 56/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0686 - accuracy: 0.9820 - val_loss: 0.5291 - val_accuracy: 0.8397
#
# Epoch 00056: val_accuracy did not improve from 0.84631
# Epoch 57/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0671 - accuracy: 0.9815 - val_loss: 0.5250 - val_accuracy: 0.8372
#
# Epoch 00057: val_accuracy did not improve from 0.84631
# Epoch 58/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0656 - accuracy: 0.9826 - val_loss: 0.5205 - val_accuracy: 0.8392
#
# Epoch 00058: val_accuracy did not improve from 0.84631
# Epoch 59/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0713 - accuracy: 0.9803 - val_loss: 0.5232 - val_accuracy: 0.8430
#
# Epoch 00059: val_accuracy did not improve from 0.84631
# Epoch 60/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0717 - accuracy: 0.9807 - val_loss: 0.5307 - val_accuracy: 0.8442
#
# Epoch 00060: val_accuracy did not improve from 0.84631
# Epoch 61/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0646 - accuracy: 0.9833 - val_loss: 0.5255 - val_accuracy: 0.8380
#
# Epoch 00061: val_accuracy did not improve from 0.84631
# Epoch 62/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0677 - accuracy: 0.9828 - val_loss: 0.5207 - val_accuracy: 0.8401
#
# Epoch 00062: val_accuracy did not improve from 0.84631
# Epoch 63/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0658 - accuracy: 0.9809 - val_loss: 0.5223 - val_accuracy: 0.8405
#
# Epoch 00063: val_accuracy did not improve from 0.84631
# Epoch 64/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0694 - accuracy: 0.9806 - val_loss: 0.5247 - val_accuracy: 0.8401
#
# Epoch 00064: val_accuracy did not improve from 0.84631
# Epoch 65/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0624 - accuracy: 0.9838 - val_loss: 0.5231 - val_accuracy: 0.8409
#
# Epoch 00065: val_accuracy did not improve from 0.84631
# Epoch 66/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0656 - accuracy: 0.9828 - val_loss: 0.5218 - val_accuracy: 0.8405
#
# Epoch 00066: val_accuracy did not improve from 0.84631
# Epoch 67/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0665 - accuracy: 0.9833 - val_loss: 0.5209 - val_accuracy: 0.8413
#
# Epoch 00067: val_accuracy did not improve from 0.84631
# Epoch 68/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0678 - accuracy: 0.9825 - val_loss: 0.5201 - val_accuracy: 0.8426
#
# Epoch 00068: val_accuracy did not improve from 0.84631
# Epoch 69/100
# 600/600 [==============================] - 12s 20ms/step - loss: 0.0633 - accuracy: 0.9840 - val_loss: 0.5265 - val_accuracy: 0.8413
#
# Epoch 00069: val_accuracy did not improve from 0.84631
# Epoch 70/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0652 - accuracy: 0.9852 - val_loss: 0.5233 - val_accuracy: 0.8405
#
# Epoch 00070: val_accuracy did not improve from 0.84631
# Epoch 71/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0669 - accuracy: 0.9824 - val_loss: 0.5233 - val_accuracy: 0.8417
#
# Epoch 00071: val_accuracy did not improve from 0.84631
# Epoch 72/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0635 - accuracy: 0.9847 - val_loss: 0.5222 - val_accuracy: 0.8426
#
# Epoch 00072: val_accuracy did not improve from 0.84631
# Epoch 73/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0631 - accuracy: 0.9842 - val_loss: 0.5219 - val_accuracy: 0.8417
#
# Epoch 00073: val_accuracy did not improve from 0.84631
# Epoch 74/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0669 - accuracy: 0.9839 - val_loss: 0.5204 - val_accuracy: 0.8426
#
# Epoch 00074: val_accuracy did not improve from 0.84631
# Epoch 75/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0660 - accuracy: 0.9822 - val_loss: 0.5250 - val_accuracy: 0.8401
#
# Epoch 00075: val_accuracy did not improve from 0.84631
# Epoch 76/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0636 - accuracy: 0.9822 - val_loss: 0.5301 - val_accuracy: 0.8388
#
# Epoch 00076: val_accuracy did not improve from 0.84631
# Epoch 77/100
# 600/600 [==============================] - 11s 19ms/step - loss: 0.0638 - accuracy: 0.9851 - val_loss: 0.5203 - val_accuracy: 0.8421
#
# Epoch 00077: val_accuracy did not improve from 0.84631
# Epoch 78/100
# 600/600 [==============================] - 12s 20ms/step - loss: 0.0621 - accuracy: 0.9850 - val_loss: 0.5219 - val_accuracy: 0.8388
#
# Epoch 00078: val_accuracy did not improve from 0.84631
# Epoch 79/100
# 600/600 [==============================] - 12s 20ms/step - loss: 0.0622 - accuracy: 0.9824 - val_loss: 0.5217 - val_accuracy: 0.8405
#
# Epoch 00079: val_accuracy did not improve from 0.84631
# Epoch 80/100
# 600/600 [==============================] - 12s 20ms/step - loss: 0.0636 - accuracy: 0.9852 - val_loss: 0.5296 - val_accuracy: 0.8405
#
# Epoch 00080: val_accuracy did not improve from 0.84631
# Epoch 81/100
# 600/600 [==============================] - 12s 19ms/step - loss: 0.0591 - accuracy: 0.9884 - val_loss: 0.5196 - val_accuracy: 0.8434
#
# Epoch 00081: val_accuracy did not improve from 0.84631
# Epoch 82/100
# 600/600 [==============================] - 12s 20ms/step - loss: 0.0618 - accuracy: 0.9856 - val_loss: 0.5200 - val_accuracy: 0.8430
#
# Epoch 00082: val_accuracy did not improve from 0.84631
# Epoch 83/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0666 - accuracy: 0.9828 - val_loss: 0.5202 - val_accuracy: 0.8413
#
# Epoch 00083: val_accuracy did not improve from 0.84631
# Epoch 84/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0608 - accuracy: 0.9874 - val_loss: 0.5210 - val_accuracy: 0.8409
#
# Epoch 00084: val_accuracy did not improve from 0.84631
# Epoch 85/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0631 - accuracy: 0.9872 - val_loss: 0.5177 - val_accuracy: 0.8434
#
# Epoch 00085: val_accuracy did not improve from 0.84631
# Epoch 86/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0617 - accuracy: 0.9850 - val_loss: 0.5217 - val_accuracy: 0.8434
#
# Epoch 00086: val_accuracy did not improve from 0.84631
# Epoch 87/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0607 - accuracy: 0.9841 - val_loss: 0.5236 - val_accuracy: 0.8380
#
# Epoch 00087: val_accuracy did not improve from 0.84631
# Epoch 88/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0612 - accuracy: 0.9855 - val_loss: 0.5207 - val_accuracy: 0.8380
#
# Epoch 00088: val_accuracy did not improve from 0.84631
# Epoch 89/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0613 - accuracy: 0.9857 - val_loss: 0.5221 - val_accuracy: 0.8434
#
# Epoch 00089: val_accuracy did not improve from 0.84631
# Epoch 90/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0577 - accuracy: 0.9860 - val_loss: 0.5222 - val_accuracy: 0.8417
#
# Epoch 00090: val_accuracy did not improve from 0.84631
# Epoch 91/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0622 - accuracy: 0.9849 - val_loss: 0.5217 - val_accuracy: 0.8380
#
# Epoch 00091: val_accuracy did not improve from 0.84631
# Epoch 92/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0621 - accuracy: 0.9856 - val_loss: 0.5262 - val_accuracy: 0.8413
#
# Epoch 00092: val_accuracy did not improve from 0.84631
# Epoch 93/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0632 - accuracy: 0.9843 - val_loss: 0.5211 - val_accuracy: 0.8409
#
# Epoch 00093: val_accuracy did not improve from 0.84631
# Epoch 94/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0657 - accuracy: 0.9840 - val_loss: 0.5223 - val_accuracy: 0.8401
#
# Epoch 00094: val_accuracy did not improve from 0.84631
# Epoch 95/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0587 - accuracy: 0.9873 - val_loss: 0.5310 - val_accuracy: 0.8413
#
# Epoch 00095: val_accuracy did not improve from 0.84631
# Epoch 96/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0595 - accuracy: 0.9873 - val_loss: 0.5219 - val_accuracy: 0.8397
#
# Epoch 00096: val_accuracy did not improve from 0.84631
# Epoch 97/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0631 - accuracy: 0.9837 - val_loss: 0.5208 - val_accuracy: 0.8421
#
# Epoch 00097: val_accuracy did not improve from 0.84631
# Epoch 98/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0600 - accuracy: 0.9873 - val_loss: 0.5174 - val_accuracy: 0.8430
#
# Epoch 00098: val_accuracy did not improve from 0.84631
# Epoch 99/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0647 - accuracy: 0.9834 - val_loss: 0.5214 - val_accuracy: 0.8421
#
# Epoch 00099: val_accuracy did not improve from 0.84631
# Epoch 100/100
# 600/600 [==============================] - 11s 18ms/step - loss: 0.0620 - accuracy: 0.9857 - val_loss: 0.5237 - val_accuracy: 0.8426
#
# Epoch 00100: val_accuracy did not improve from 0.84631

# %%
model = load_model(modelName)

df_test = pd.DataFrame()

Y_test_normal = np.argmax(Y_test, axis=-1)

print(Y_test_normal.shape)

df_test['type'] = Y_test_normal

df_test = df_test.reset_index(drop=True)

df_test.head(10)

def fixImages(folder_name):
    for img_name in os.listdir(folder_name):
        try:
            readImages(folder_name + img_name)
        except Exception as ex:
            os.remove(folder_name + img_name)

# %%
preds = np.argmax(model.predict(X_test/255.0), axis=-1)

df_test['preds'] = np.round(preds)
df_test['preds'] = df_test['preds'].apply(np.int)

wrongs_df = df_test.loc[df_test['type'] != df_test['preds']]

print(f"Doğruluk oranı %{100 - (len(wrongs_df) * 100 / len(df_test))}")

df_test.head(10)
# Out:
# 2401 hücre fotoğrafı arasından 369 tanesi yanlış tahmin edildi. Doğruluk oranı %84.6314035818409
#    type  preds
# 0     1      0
# 1     1      0
# 2     1      1
# 3     1      1
# 4     0      0
# 5     1      1
# 6     1      1
# 7     1      1
# 8     0      0
# 9     0      1

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

cm1 = confusion_matrix(df_test[['type']], df_test['preds'])
sn.heatmap(cm1, annot=True, annot_kws={"size": 16}, fmt="d")

total1=sum(sum(cm1))
#####from confusion matrix calculate accuracy
accuracy1=(cm1[0,0]+cm1[1,1])/total1
print ('Accuracy : ', accuracy1)

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Sensitivity : ', sensitivity1 )

specificity1 = cm1[1,1]/(cm1[1,0]+cm1[1,1])
print('Specificity : ', specificity1)
# Out:
# Accuracy :  0.846314035818409
# Sensitivity :  0.9174836601307189
# Specificity :  0.7723024638912489

# %%
plt.figure(figsize=(10,10))
plt.axis('Off')

start_from = 10

for i in range(1, 10):
    plt.subplot(3,3,i)
    test_image = X_test[i + start_from, :, :, 0]
    plt.imshow((test_image), cmap=plt.cm.bone)

    true = df_test.loc[i + start_from, 'type']
    pred = df_test.loc[i + start_from, 'preds']
    result = 'True: ' + str(int(true)) + ' Pred: ' + str(pred)

    plt.title(result, fontsize=14)
    plt.axis('off')


plt.tight_layout()
plt.show()
